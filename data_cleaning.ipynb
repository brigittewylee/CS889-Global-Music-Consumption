# %%
import pandas as pd

# adds back missing artists
df = pd.read_csv("datasets/monthly_top.csv")
df1 = pd.read_csv("datasets/complete_dataset_single_artist.csv")

df1['artists'] = df[['artists']]

df1.to_csv("final_cleaned_data.csv")
